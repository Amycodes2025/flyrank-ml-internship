# %% [markdown]
# <a href="https://colab.research.google.com/github/Amycodes2025/flyrank-ml-internship/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I picked Lane 2: Refresh/Content Opportunity scoring. This lane is about ranking pages so editors know which ones to fix first. I chose it because I already worked with this  exact idea in Notebook 01 (a hand-made rule for flagging pages) and Notebook 02 (a model that beat that rule). Since I already understand this workflow, I want to go deeper into it for my capstone

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# My work helps decide which pages a content editor should fix first, out of thousands of pages when they only have time for a few dozen. The person who acts on it is a content editor, they pick pages from my ranked list and rewrite or update them. If my recommendation is wrong, the editor wastes hours fixing a page that wasn't actually going to improve while a page that really needed help gets ignored instead.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import os, subprocess
REPO_URL = "https://github.com/Amycodes2025/flyrank-ml-internship"
REPO_DIR = "flyrank-ml-internship"
if not os.path.isdir(REPO_DIR):
  subprocess.run(["git", "clone", "--depth", "1", REPO_URL, REPO_DIR], check=True)
os.chdir(REPO_DIR)
print("Working dir:", os.getcwd())
# Out:
# Working dir: /content/flyrank-ml-internship

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

# Number 1: How many pages are actually candidates for this lane?
stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"Stale + visible pages (real refresh candidates): {stale_visible} out of {len(df)}")

# Number 2: How well did the starter model do at ranking these
print("From my notebook 02 experiment: depth-3 tree Precision@50 = 0.720 vs depth-2 = 0.600")

# Number 3: From the lane guide's verified pipeline results
print("From the full starter pipeline: baseline rules Precision@50 = 0.240, random forest = 0.740")
# Out:
# Stale + visible pages (real refresh candidates): 17 out of 30000
# From my notebook 02 experiment: depth-3 tree Precision@50 = 0.720 vs depth-2 = 0.600
# From the full starter pipeline: baseline rules Precision@50 = 0.240, random forest = 0.740

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# My work can say which pages look worth reviewing first based on patterns I actually observed and measured in the data like how stale, visible or well positioned a page is. It's decision support: it helps a human editor prioritize their limited time not a decision made on its own. What it can't say: it can't prove that refreshing a flagged page will actually cause it to recover that would require a real experiment not just this data. It also can't make any claims about how Google's search algorithm actually works, it only reflects patterns in this sepcific

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [x] Every section above is filled — markdown thinking AND the code that backs it
# - [X] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [X] No client names, URLs, or private queries anywhere
# - [X] My claims use careful words: observed, measured, directional, decision-support
# - [X] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
